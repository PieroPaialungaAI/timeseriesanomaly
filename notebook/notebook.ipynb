# %%
import sys
sys.path.append('..')

from data import DataGenerator

# Initialize and generate data
data_generator = DataGenerator()
data = data_generator.generate_data()
data_generator.export_data()
#data_generator.plot_multiple(num_plot=5)

# %%
# Check metadata for first few series
metadata = data_generator.get_metadata()
for meta in metadata[:5]:
    print(f"Series {meta['series_idx']}: {[a['type'] for a in meta['anomalies']]}")
# Out:
# Series 0: ['level_shift']
# Series 1: ['trend']
# Series 2: ['point_anomaly']
# Series 3: ['level_shift']
# Series 4: ['level_shift']

# %%
from anomaly_detector import AnomalyDetector

detector = AnomalyDetector(x=data_generator.x, y=data_generator.y) #We are using this for all the anomalies
result = detector.detect_trend_anomaly(series_idx=0) #This detects the trend for a single time series
all_results = detector.detect_all_trends() # This detects the trends for all the time series
trend_indices = detector.get_series_with_trend() # This gets the indices of series with significant trend (p < 0.05)

# %%
# Plot single series with trend
detector.plot_trend_anomalies(num_plot=5, only_with_trend=True)  # All series
# Out:
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/trend_anomalies_5.png
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/trend_anomalies_5.svg

# %%
result = detector.detect_volatility_anomaly(series_idx=5) #Do the volatility for a single time series
results = detector.detect_all_volatilities() #Do the volatility for all the time series
high_vol_indices = detector.get_series_with_high_volatility() #Get the indices of the series with high volatility

# %%
# Plot single series volatility
detector.plot_volatility_anomalies(num_plot=5, only_high_volatility=True)
# Out:
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/volatility_anomalies_5.png
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/volatility_anomalies_5.svg

# %%
result = detector.detect_point_anomaly(series_idx=5) # Detect point anomalies for single series
results = detector.detect_all_point_anomalies() # Detect for all series
indices = detector.get_series_with_point_anomalies() # Get indices of series that have point anomalies

# %%
detector.plot_point_anomalies(num_plot=5, only_with_anomalies=True)
# Out:
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/point_anomalies_5.png
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/point_anomalies_5.svg

# %%
result = detector.detect_dataset_level_anomalies()
indices = detector.get_dataset_level_anomalies()
detector.plot_dataset_level_anomalies(num_plot=5)
# Out:
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/dataset_level_anomalies_2.png
# Saved: /Users/pieropaialunga/Desktop/TDS/TimeSeriesAnomalies/timeseriesanomaly/notebook/../images/dataset_level_anomalies_2.svg
